# %%
import numpy as np
import pandas as pd
import sklearn
import xlrd
import matplotlib.pylab as py
import nltk as nltk
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap

# %matplotlib inline

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
PrimaryEmotion = pd.read_csv('emotion.xls.csv')
PrimaryEmotion
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-4177f27e8e58> in <module>()
# ----> 1 PrimaryEmotion = pd.read_csv('emotion.xls.csv')
#       2 PrimaryEmotion
#
# /ext/sage/sage-8.3_1804/local/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# /ext/sage/sage-8.3_1804/local/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# /ext/sage/sage-8.3_1804/local/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# /ext/sage/sage-8.3_1804/local/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# /ext/sage/sage-8.3_1804/local/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# IOError: File emotion.xls.csv does not exist

# %%
sentences = PrimaryEmotion['sentence']
sentences.head()

# %%
# Here we tokenize the data into individual words based on whitespaces. There are other tokenizing methods which we could use, I just decided to try this one first. 

sentence = "The brown fox wasn't that quick and he couldn't jump over the fox, and he didn't win the race."

print(word_tokenize(sentence))

# %%
# In this first step I am changing all the words to lower case. 
PrimaryEmotion['sentence'] = PrimaryEmotion['sentence'].apply(lambda x: " ".join(x.lower() for x in x.split()))

PrimaryEmotion['sentence'].head()

# %%
# In this line I am removing punctuation.
PrimaryEmotion['sentence'] = PrimaryEmotion['sentence'].str.replace('[^\w\s]','')

PrimaryEmotion['sentence'].head()
# Out:
# 0    how much of the forecast was genuine and how m...
# 1    i did touch them one time you see but of cours...
# 2    we find that choice theorists admit that they ...
# 3                  well here i am with an olive branch
# 4    its rudder and fin were both knocked out and a...
# Name: sentence, dtype: object

# %%
# Now I remove stop words.
# Note that I used a package that has predefined "stopwords" you can google the package "nltk stopwords list" to see which words are in the list. This is something we could edit to whatever we want. 

from nltk.corpus import stopwords

stop = stopwords.words('english')

PrimaryEmotion['sentence'] = PrimaryEmotion['sentence'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

PrimaryEmotion['sentence'].head()
# Out:
# 0          much forecast genuine much fixed moot point
# 1             touch one time see course nothing wanted
# 2    find choice theorists admit introduce style mo...
# 3                                    well olive branch
# 4    rudder fin knocked fourfootlong gash shell mea...
# Name: sentence, dtype: object

# %%
# This block finds the "root" word. 
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

sb = SnowballStemmer("english")

for w in PrimaryEmotion['sentence']:
    print(sb.stem(w))
# Out:
# WARNING: Some output was deleted.
