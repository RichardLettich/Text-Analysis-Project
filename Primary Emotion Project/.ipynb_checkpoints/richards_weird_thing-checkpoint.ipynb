# %%
from __future__ import unicode_literals, print_function
import plac
import random
from pathlib import Path
import thinc.extra.datasets
import pandas as pd

print("hola")

import spacy
from spacy.util import minibatch, compounding

from sklearn.feature_extraction.text import CountVectorizer
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
import re


nlp = spacy.blank('en')

textcat = nlp.create_pipe('textcat')
nlp.add_pipe(textcat, last=True)


PrimaryEmotion = pd.read_csv('emotion.xls.csv')
ProjectData = PrimaryEmotion[['emotion','sentence']]


emotion_list = ProjectData['emotion']
sentence_list = ProjectData['sentence']

print("hola")


sorted_list = []
sorted_emo = []
c = [emotion_list, sentence_list]


#######Sorts and counts Happy emotions
for i in range(len(c[1])):
    if (c[0][i] == 'Joy' or c[0][i] == 'Love' or c[0][i] == 'Optimism' or c[0][i] == 'Awe' or c[0][i] == 'Trust'):
        sorted_list.append(sentence_list[i])
        sorted_emo.append(emotion_list[i])
  #  else:
   #     sorted_emo.append("sad")



max_fatures = 8000
tokenizer = Tokenizer(num_words=max_fatures, split=' ')
tokenizer.fit_on_texts(sentence_list)
X = tokenizer.texts_to_sequences(sentence_list)
X = pad_sequences(X)

embed_dim = 128
lstm_out = 196

model = Sequential()
model.add(Embedding(max_fatures, embed_dim,input_length = X.shape[1]))
model.add(SpatialDropout1D(0.4))
model.add(LSTM(lstm_out, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(18,activation='softmax'))
model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
print(model.summary())

Y = pd.get_dummies(emotion_list).values
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.33, random_state = 42)
print(X_train.shape,Y_train.shape)
print(X_test.shape,Y_test.shape)

batch_size = 128
model.fit(X_train, Y_train, epochs = 50, batch_size=batch_size, verbose = 2)

validation_size = 12
# Out:
# hola
# hola
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_2 (Embedding)      (None, 75, 128)           1024000
# _________________________________________________________________
# spatial_dropout1d_2 (Spatial (None, 75, 128)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 196)               254800
# _________________________________________________________________
# dense_2 (Dense)              (None, 18)                3546
# ...
# Total params: 1,282,346
# Trainable params: 1,282,346
# Non-trainable params: 0
# _________________________________________________________________
# None
# (1691, 75) (1691, 18)
# (833, 75) (833, 18)
# Epoch 1/50
#  - 9s - loss: 2.7930 - acc: 0.1892
# Epoch 2/50
#  - 7s - loss: 2.6131 - acc: 0.1591
# Epoch 3/50
#  - 8s - loss: 2.5639 - acc: 0.2123
# Epoch 4/50
# ...

# %%
validation_size = 10

X_validate = X_test[-validation_size:]
Y_validate = Y_test[-validation_size:]
X_test = X_test[:-validation_size]
Y_test = Y_test[:-validation_size]
score,acc = model.evaluate(X_test, Y_test, verbose = 2, batch_size = batch_size)
print("score: %.2f" % (score))
print("acc: %.2f" % (acc))
predictions = model.predict(X_test, batch_size=batch_size)


tokenizer1 = Tokenizer(num_words=max_fatures, split=' ')
tokenizer1.fit_on_texts(sentence_list)
T = tokenizer.texts_to_sequences(sentence_list)
T = pad_sequences(X)

test = model.predict(T, batch_size=batch_size)
for i,j,k in zip(test,sentence_list, emotion_list):
    pos = i.tolist().index(max(i))
    print("\n\n")
    print(j)
    print("\nPredicted emotion: ", emotion_list.unique()[pos])
    print("Actual emotion   : ", k)
# Out:
# score: 5.37
# acc: 0.20
#
#
#
# How much of the forecast was genuine and how much was fixed, it is a moot point.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# I did touch them one time you see but of course there was nothing doing, he wanted me.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# We find that choice theorists admit that they introduce a style of moral paternalism at odds with liberal values.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# Well, here I am with an olive branch.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# Its rudder and fin were both knocked out, and a four-foot-long gash in the shell meant even repairs on the bank were out of the question.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# Over my dead body are you arresting him.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Anger
#
#
#
# ...
