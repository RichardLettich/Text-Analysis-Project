# %%
from __future__ import unicode_literals, print_function
import plac
import random
from pathlib import Path
import thinc.extra.datasets
import pandas as pd
import spacy
from spacy.util import minibatch, compounding
from sklearn.feature_extraction.text import CountVectorizer
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
import re
from numpy import array, unique, array_equal
max_fatures = 1000


def load_data():
    print("Loading Data...")
    PrimaryEmotion = pd.read_csv('emotion.xls.csv')
    print("Data Loaded")
    return (PrimaryEmotion['sentence'], array(PrimaryEmotion['emotion']))



def sort_to_2_emotions(sentence_list, emotion_list):
    sorted_list = []
    sorted_emo = []
    for (data, emo) in zip(sentence_list, emotion_list):
        if (emo == 'Joy' or emo == 'Love' or emo == 'Optimism' or emo == 'Awe' or emo == 'Trust'):
            sorted_list.append(data)
            sorted_emo.append("positive")
        if (emo == 'anger' or emo == 'Disgust' or emo == 'Sadness' or emo == 'Aggression' or emo == 'Contempt' or emo == 'Disapproval' or emo == 'Remorse'):
            sorted_list.append(data)
            sorted_emo.append("negative")
    return (sorted_list, sorted_emo)



def tokenize(sentences):
    print("Tokenizing...")
    tokenizer = Tokenizer(num_words=max_fatures, split=' ')
    tokenizer.fit_on_texts(sentences)
    X = tokenizer.texts_to_sequences(sentences)
    X = pad_sequences(X)
    print("Tokenization Completed")
    return X



def train(tokened_sentences, emotion_list):
    print("Training...")
    embed_dim = 128
    lstm_out = 196
    test_percent=.33

    model = Sequential()
    model.add(Embedding(max_fatures, embed_dim,input_length = tokened_sentences.shape[1]))
    model.add(SpatialDropout1D(0.4))
    model.add(LSTM(lstm_out, dropout=0.2, recurrent_dropout=0.2))
    
    # len(set(emotion_list)) is a hacky way of geting the number of unique elements
    # in a regualar python list (non-numpy)
    model.add(Dense(unique(emotion_list).size,activation='softmax'))
    model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
    #print(model.summary())

    Y = pd.get_dummies(emotion_list).values
    X_train, X_test, Y_train, Y_test = train_test_split(tokened_sentences,Y, test_size = test_percent, random_state = 42)
    #print(X_train.shape,Y_train.shape)
    #print(X_test.shape,Y_test.shape)

    batch_size = 32
    model.fit(X_train, Y_train, epochs = 10, batch_size=batch_size, verbose = 1)
    print("Training Completed")
    print("Testing Against Control... (% of the data) ", test_percent)
    score,acc = model.evaluate(X_test, Y_test, verbose = 2, batch_size = batch_size)
    print("Score   :", score)
    print("Accuracy:", acc)
    return (model, X_test)

### When Splitting data (train_test_split), we don't retain where in the 
### origional set the data is located, thus it takes
### a little trickery to see the results while while only testing against untrained data

def test(model, X_test, tokenized_data, sentence_list, emotion_list):
    predictions = model.predict(tokenized_data, batch_size=32)
    error = 0
    for i in range(len(predictions)):
     
        #  "If the current tokenized data array is in X_test (untrained tokenized arrays)
        
        if(any(array_equal(tokenized_data[i], x) for x in X_test)):
            pos = list(predictions[i]).index(max(predictions[i]))
            print("\n\n")
            print(sentence_list[i])
            print("\nPredicted emotion: ", unique(emotion_list)[pos])
            print("Actual emotion   : ", emotion_list[i])
            if (unique(emotion_list)[pos] != emotion_list[i]):
                error += 1
    print("%  Accuracy when against untrained set: ", 1- (float(error) / len(X_test)))

#################################
#############MAIN################
#################################
#   jupyter notebook is weird   #




(sentence_list, emotion_list) = load_data()


### Comment the Below line for all 18 emotions. This sorts into "positive" and "negative"
#sentence_list, emotion_list = sort_to_2_emotions(sentence_list, emotion_list)

tokenized_data = tokenize(sentence_list)

(model, X_test) = train(tokenized_data, emotion_list)

test(model, X_test, tokenized_data, sentence_list, emotion_list)
# Out:
# Using TensorFlow backend.
# Loading Data...
# Data Loaded
# Tokenizing...
# Tokenization Completed
# Training...
# Epoch 1/10
# 1691/1691 [==============================] - 9s 5ms/step - loss: 2.6643 - acc: 0.1952
# Epoch 2/10
# 1691/1691 [==============================] - 7s 4ms/step - loss: 2.5801 - acc: 0.2123
# Epoch 3/10
# 1691/1691 [==============================] - 8s 5ms/step - loss: 2.5364 - acc: 0.2129
# Epoch 4/10
# 1691/1691 [==============================] - 7s 4ms/step - loss: 2.4455 - acc: 0.2490
# Epoch 5/10
# 1691/1691 [==============================] - 7s 4ms/step - loss: 2.2448 - acc: 0.3353
# Epoch 6/10
# 1691/1691 [==============================] - 7s 4ms/step - loss: 2.0408 - acc: 0.4063
# Epoch 7/10
# 1691/1691 [==============================] - 7s 4ms/step - loss: 1.8526 - acc: 0.4571
# Epoch 8/10
# 1691/1691 [==============================] - 7s 4ms/step - loss: 1.6818 - acc: 0.5003
# Epoch 9/10
# 1691/1691 [==============================] - 8s 4ms/step - loss: 1.5353 - acc: 0.5494
# Epoch 10/10
# 1691/1691 [==============================] - 7s 4ms/step - loss: 1.4043 - acc: 0.5878
# Training Completed
# Testing Against Control... (% of the data)  0.33
# Score   : 3.038080804738678
# Accuracy: 0.21368547418967587
#
#
#
# Aggie finally found the cat a good home and from that day onwards she had kept up a running battle with her mice.
#
#
# Predicted emotion:  Love
# Actual emotion   :  Optimism
#
#
#
# So, you know, whilst I'm a little bit reluctant, in a way I think that's water under the bridge, and in my view actually the extension improves it all.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Sadness
#
#
#
# Well, what about the view, let me kind of play devil's advocate here against Freud and Bullett.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Anticipation
#
#
#
# Here we are at loggerheads with the rival practice, and I've gone and fallen in love with Robert's assistant.
#
# Predicted emotion:  Love
# Actual emotion   :  Love
#
#
#
# For a brother and sister act, there was certainly no love lost between them.
#
# Predicted emotion:  Contempt
# Actual emotion   :  Surprise
#
#
#
# Then, in 1981, all hell broke loose in the Cambridge English Faculty.
#
# Predicted emotion:  Fear
# Actual emotion   :  Sadness
#
#
#
# Dear Father Christmas, I have a bone to pick with you.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Anger
#
#
#
# You sound cheesed off, what's the matter?
#
# Predicted emotion:  Anger
# Actual emotion   :  Anger
#
#
#
# Do not mention them, they would eat you alive.
#
# Predicted emotion:  Contempt
# Actual emotion   :  Submission
#
#
#
# He was fit to be tied when I separated from Hugh, and he seems to blame me for the whole thing.
#
# Predicted emotion:  Joy
# Actual emotion   :  Sadness
#
#
#
# I suppose you're planning to make me foam at the mouth and gabble in obsolete tongues.
#
# Predicted emotion:  Joy
# Actual emotion   :  Disgust
#
#
#
# Now though, the gloves are off.
#
# Predicted emotion:  Anticipation
# Actual emotion   :  Aggression
#
#
#
# Just as he will not tolerate questions about his private life, so he will also go ballistic if bureacrats attempt to meddle in his creative decisions.
#
# Predicted emotion:  Ambiguous
# Actual emotion   :  Anger
#
#
#
# So I mean you, you just mind your own business.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# Emily has a quick temper.
#
# Predicted emotion:  Anger
# Actual emotion   :  Love
#
#
#
# Was it going to be a rap on the knuckles for quality?
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# She could scream blue murder, but half an hour later would be the life of a dinner party, for she was very vain and never missed a chance to show herself off.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Ambiguous
#
#
#
# It's steamed up between the layers is that what you're looking at.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Anger
#
#
#
# An eighteen year old married an eighty one year old, now that is going too far.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Disapproval
#
#
#
# Because he was a bundle of nerves, he couldn't keep still.
#
# Predicted emotion:  Fear
# Actual emotion   :  Disapproval
#
#
#
# Hold your breath and push, seems to work on me.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Optimism
#
#
#
# Tongue tied.
#
# Predicted emotion:  Surprise
# Actual emotion   :  Surprise
#
#
#
# Once it was known that Terry Gill was wanted for questioning, a young constable who knew him, all bright eyed and bushy tailed, pointed out that his van had been parked in the car-park all day within fifty yards of the Incident Room.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Neutral
#
#
#
# He had me on the edge of my seat a couple of times.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Anticipation
#
#
#
# His performance at fever pitch.
#
# Predicted emotion:  Anticipation
# Actual emotion   :  Love
#
#
#
# So I can't go away in the autumn now cos that's just when everybody starts raring to go and wanting to get started on next year's programme.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Sadness
#
#
#
# But I was, I was bored to tears.
#
# Predicted emotion:  Sadness
# Actual emotion   :  Sadness
#
#
#
# I didn't know I could have such a good time so close to home.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Surprise
#
#
#
# He waited to be instructed, what else a Rifleman could do to be less like a fish out of water in a battalion of Grenadiers.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# Try to get a grip on yourself and tell me about it.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# Jane could not get worked up about any car.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# How did he go to pieces, when you say he went to pieces?
#
# Predicted emotion:  Ambiguous
# Actual emotion   :  Ambiguous
#
#
#
# Both of them were breathing hard, such a hurry and scramble of lips, hands, such a heat inside and between them, he stuffed one small breast into his mouth and then the other, giving her the same churn of astonished guilty pleasure as when she lay on her bed in the afternoons and read the forbidden books she smuggled home from the library.
#
# Predicted emotion:  Joy
# Actual emotion   :  Anticipation
#
#
#
# So I go, have a job to find it he just looks at me hard as nails.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Anger
#
#
#
# I was, as a newly arrived curate, somewhat taken aback and went home to lick my wounds.
#
# Predicted emotion:  Fear
# Actual emotion   :  Surprise
#
#
#
# Now that's a quick fix and hasn't cost anything, hasn't put anybody's nose out of joint.
#
# Predicted emotion:  Sadness
# Actual emotion   :  Love
#
#
#
# Why open old wounds?
#
# Predicted emotion:  Anger
# Actual emotion   :  Disapproval
#
#
#
# But her silence, and her eyebrows, speak volumes.
#
# Predicted emotion:  Joy
# Actual emotion   :  Neutral
#
#
#
# Don't tear your hair out.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Anger
#
#
#
# So these are hangings erm hung on tenterhooks directly hammered straight into the wall.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# Suddenly Water Gypsy' s hitherto charming interior seemed claustrophobic, and she decided a brisk walk along the towpath might blow away the cobwebs and the fit of blues that bedevilled her
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Optimism
#
#
#
# Chill out, Tal.
#
# Predicted emotion:  Joy
# Actual emotion   :  Neutral
#
#
#
# Because you know they came up, they were full of the joys of spring, looking around, chatting to their friends.
#
# Predicted emotion:  Joy
# Actual emotion   :  Joy
#
#
#
# Both of them were breathing hard, such a hurry and scramble of lips, hands, such a heat inside and between them, he stuffed one small breast into his mouth and then the other, giving her the same churn of astonished guilty pleasure as when she lay on her bed in the afternoons and read the forbidden books she smuggled home from the library.
#
# Predicted emotion:  Joy
# Actual emotion   :  Joy
#
#
#
# But you can be sure that you'll have the time of your life.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Anticipation
#
#
#
# It's only when you let your hair down that others can see the real person hiding under the hat.
#
# Predicted emotion:  Anticipation
# Actual emotion   :  Neutral
#
#
#
# By the time they were ready to leave she was having to use every ounce of effort to convince Andr that no, she didn't want to paint the town red, or any other colour, for that matter, and no, she didn't want to have any candlelit dinners with him.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# Come off it, pull the other one.
#
# Predicted emotion:  Joy
# Actual emotion   :  Aggression
#
#
#
# No punch line.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# He is not a flamboyant man, nor is he much of a social butterfly except by comparison with the rest of his senior colleagues who tend to keep to their own counsel and lives in Barnes.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# It is not clear where Sir Trevor learned to tickle the ivories.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Ambiguous
#
#
#
# After that, the world is your oyster, as they say.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Joy
#
#
#
# For the past five days now she had been living somewhere on cloud nine, and had decided that she might just as well set up home there, as it was such a wonderful place to be.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Joy
#
#
#
# Mr Crangle was grinning from ear to ear.
#
# Predicted emotion:  Joy
# Actual emotion   :  Joy
# They're going to have to come out of the forests,' he replied, with a grin like a Cheshire cat.
#
# Predicted emotion:  Joy
# Actual emotion   :  Joy
#
#
#
# The voice sings along with the song, then turns into a hum. Your heart sinks. You were hoping he was alone in the house.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Sadness
#
#
#
# It's a little lad and I looked through a window, I could see Judith holding this baby but you had to walk round to get to her and I knew before you'd got there and you were all over the moon about this little baby and everything.
#
# Predicted emotion:  Joy
# Actual emotion   :  Neutral
#
#
#
# Everybody else was in raptures. And I thought, oh not Norma.
#
# Predicted emotion:  Joy
# Actual emotion   :  Disapproval
#
#
#
# Constance was in seventh heaven, the dresses, the hats, the model girls, everything appeared perfect to her.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Joy
#
#
#
# These are things you can't afford to lose, not at this time of your life.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Disapproval
#
#
#
# We have gone from being the bread basket of Central America to being its basket case.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Disapproval
#
#
#
# If you think about it long enough you'll go nuts.
#
# Predicted emotion:  Anger
# Actual emotion   :  Anticipation
#
#
#
# I swear you have a screw loose.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Disgust
#
#
#
# I must have gone stark raving mad.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Remorse
#
#
#
# I'm gonna get stir crazy not being able to play badminton I know, and I score, it's gonna drive me crazy.
#
# Predicted emotion:  Sadness
# Actual emotion   :  Sadness
#
#
#
# This picture of Dreadnought was so wide of the mark that Willis found it better to say nothing, simply making a gesture which had something in common with a petty officer's salute.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# Servants bow and scrape.
#
# Predicted emotion:  Surprise
# Actual emotion   :  Submission
#
#
#
# Yes, the done thing for driving horses to canter or gallop on the road, they never ever should.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# The government takes the view that President Clinton was simply addressing domestic critics of his foreign policy and that his complaints shouldn't set the alarm bells ringing.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# Or an electric fire then you would be asking for trouble because you'd be trying to draw out.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Disapproval
#
#
#
# Someone came out of The Two Pheasants and latched the door back to the wall hospitably.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# They are the bane of my life.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Disapproval
#
#
#
# They're in a Catch 22 situation.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# The only cloud on the horizon was a boy called Dennis Dawson.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Optimism
#
#
#
# That needn't of come to a head like that really.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Disapproval
#
#
#
# It's alright but you get to the bottom of those stairs and sometimes feel lost.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Trust
#
#
#
# It's an embarrassing thing for a fault-tolerant vendor to have to say, but a bug in Guardian for the Tandem Computers Inc NonStop CLX machines caused them to reset their clocks to December 1,1983 on November 1, causing systems with time-dependent programs to go haywire.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Sadness
#
#
#
# She was in dire straits.
#
# Predicted emotion:  Surprise
# Actual emotion   :  Sadness
#
#
#
# I don't want to leave him in the lurch
#
# Predicted emotion:  Joy
# Actual emotion   :  Remorse
#
#
#
# In fact, you're a girl who's going places -- once you've untied yourself from this man who's been like a millstone around your neck for the last four years.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Optimism
#
#
#
# He did his best to paper over the cracks.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Optimism
#
#
#
# I think that everyone seems to pass the buck.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Disapproval
#
#
#
# Yeah, if at the end of the day it's a quick fix then.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Optimism
#
#
#
# But we are saved by the bell.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Joy
#
#
#
# You spell trouble, and I want you out of the way.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Anger
#
#
#
# The Governor admits there have been teething problems which need sorting out.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Disapproval
#
#
#
# The submersible rose higher in the dock, the overflowing sea rushing like a tide over their boots.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# Eight extra bullets in a tight spot could mean the difference between life and death.
#
# Predicted emotion:  Sadness
# Actual emotion   :  Fear
#
#
#
# She had to admit that he would almost certainly not see the situation as an unmitigated disaster.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Optimism
#
#
#
# But, somehow, he sensed that that would be an uphill battle.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# Well they can finally expel you but it's a vicious circle, I mean it goes on and on and on.
#
# Predicted emotion:  Submission
# Actual emotion   :  Disapproval
#
#
#
# He just took a calculated risk on the spur of the moment.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Anticipation
#
#
#
# He decided to throw caution to the wind before Selwyn came over for his tea.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Optimism
#
#
#
# Yeah, Geoff. Tell him the coast is clear.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# Treasurers suffer the erm, the occupational hazard that they always, to some extent, have to cry wolf.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Optimism
#
#
#
# Hoomey's teeth were chattering after his dice with death.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Fear
#
#
#
# Obey them to the letter and you will be well rewarded -- any bungling or playing the fool and I doubt you'll live to tell the tale
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Fear
#
#
#
# Don't you never look before you leap?
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Disapproval
#
#
#
# It's a no go area.
#
# Predicted emotion:  Fear
# Actual emotion   :  Disapproval
#
#
#
# To keep the rod upright, out of harm 's way when not in use.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Ambiguous
#
#
#
# In a recent episode of a Music Television cartoon called Beavis and Butthead, the characters play with fire.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Disapproval
#
#
#
# Phil Angell asked him what does it take to risk life and limb.
#
# Predicted emotion:  Sadness
# Actual emotion   :  Neutral
#
#
#
# Och he knows you're in safe hands like when you come round here.
#
# Predicted emotion:  Anger
# Actual emotion   :  Trust
#
#
#
# Safety in numbers.
#
# Predicted emotion:  Joy
# Actual emotion   :  Trust
#
#
#
# You really do like to sail close to the wind, don't you?
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Sadness
#
#
#
# A business worth three billion pounds a year is at stake.
#
# Predicted emotion:  Sadness
# Actual emotion   :  Fear
#
#
#
# Better watch your step next time you drink whisky.
#
# Predicted emotion:  Anticipation
# Actual emotion   :  Disapproval
#
#
#
# I could do with forty winks right now and Otley would never miss me.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# I suppose it came into my room for a few minutes to see a book I'd been telling him about, then he left and I hit the sack.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# If this were a simple and one-way movement, the answer would lie in ensuring that the record of achievement is up to date and intelligible.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Ambiguous
#
#
#
# By the time he arrived at Amanda's he was ready to drop.
#
# Predicted emotion:  Sadness
# Actual emotion   :  Submission
#
#
#
# I can not sleep a wink now.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Sadness
#
#
#
# Like the Carters', the Parsons' marriage was in turn-around, only there it was Dennis who was the sleeping partner.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# She ended a bedraggled also-ran, trailing in ninth.
#
# Predicted emotion:  Anticipation
# Actual emotion   :  Neutral
#
#
#
# Can Desert Orchid the champion bring the house down and win.
# Predicted emotion:  Anticipation
# Actual emotion   :  Anticipation
#
#
#
# Never get anything done in this life if you don't chance your arm.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Neutral
#
#
#
# You cut your own throat already when you wrote the script for Connie's disappearance.
#
# Predicted emotion:  Fear
# Actual emotion   :  Disapproval
#
#
#
# They think I'm a dead duck but it's not been a time you could write off.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Aggression
#
#
#
# When he stands alone in such a place confronted by several police officers, usually some of high rank, the dice are loaded against him, especially as he knows there is no one to corroborate him as to what exactly occurred during the interrogation, how it was conducted and how long it lasted
#
# Predicted emotion:  Neutral
# Actual emotion   :  Submission
#
#
#
# While all her instincts balked against becoming too enmeshed with Vitor, she seemed destined to fight a losing battle.
#
# Predicted emotion:  Sadness
# Actual emotion   :  Sadness
#
#
#
# Yeah but it's a flash in the pan.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Disapproval
#
#
#
# Another local team off to a flying start are Gloucester Rugby club.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Optimism
#
#
#
# This is a fool 's errand.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Disapproval
#
#
#
# But you haven't to let either of them get the better of you.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Contempt
#
#
#
# Erm, should the house go up in smoke, Theresa across the road run to her.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# Because your dad's a manager, he's got it made.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Awe
#
#
#
# Whereas before we were going up in leaps and bounds.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Ambiguous
#
#
#
# I reluctantly withdraw this motion, but I will say this, we live to fight another day.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Remorse
#
#
#
# Joe and I mean I come a long way
#
# Predicted emotion:  Optimism
# Actual emotion   :  Love
#
#
#
# If you find yourself at a low ebb this weekend don't worry.
#
# Predicted emotion:  Anticipation
# Actual emotion   :  Awe
#
#
#
# He says he's really going to make a killing.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Optimism
#
#
#
# He married someone else in 1860 and drops out of the picture.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Sadness
#
#
#
# Most athletes win honestly, but some will do anything to finish ahead of the pack, even using illegal drugs.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Disapproval
#
#
#
# She was under the impression that Charles had put the kibosh on any exclusive agreement with Barton, and most certainly nothing had been said about it.
#
# Predicted emotion:  Sadness
# Actual emotion   :  Disapproval
#
#
#
# James after the home leg, said we will have to weather the storm.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Optimism
#
#
#
# Now, was this forty thousand pounds a bolt from the blue or did you know it was coming to you?
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# It was my 85th birthday recently and out of the blue, a letter arrived from my daughter containing tickets for a four-day trip to Paris.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Surprise
#
#
#
# He had to do a double take, bumping into a filing cabinet.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Surprise
#
#
#
# Everyone looked round and Biff's jaw dropped.
#
# Predicted emotion:  Surprise
# Actual emotion   :  Surprise
#
#
#
# She almost jumped out of her skin when she saw it.
#
# Predicted emotion:  Anger
# Actual emotion   :  Surprise
#
#
#
# But for many, stories about one night-stands are more inclined to raise eyebrows than get them giggling.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Disapproval
#
#
#
# We all tend to put our hands in our pockets and stand rooted to the spot and all the rest of it but there are ways of overcoming it.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Optimism
#
#
#
# Wesley Smith Seeing is believing the videophone which takes the blind out of date.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# I say wonders will never cease I have just written a receipt  and I have put it in her envelope.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Surprise
#
#
#
# Plod could herd them all together into a group, march them to and from their destinations, depriving them along the way of all alcohol  and beat the living daylights out of any who still insisted on stepping out of line.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Fear
#
#
#
# Lapointe and the other Frenchman come to blows after the accident, or what?
#
# Predicted emotion:  Optimism
# Actual emotion   :  Aggression
#
#
#
# Now though, the gloves are off.
#
# Predicted emotion:  Anticipation
# Actual emotion   :  Anger
#
#
#
# The more likely reason for this move is a tit for tat reaction.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Contempt
#
#
#
# I've got my shoulder, my stomach er, I'm in the wars today.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Ambiguous
#
#
#
# Er, she says that she's er, there's absolutely nothing doing just at the moment.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Ambiguous
#
#
#
# I managed to win a couple of quid on Deano to score the first goal, at odds of 7-1.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Joy
#
#
#
# Indeed, it was out of the question given the dollar's enfeebled position.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Disapproval
#
#
#
# Don't you pick holes in my religion.
#
# Predicted emotion:  Anger
# Actual emotion   :  Anger
#
#
#
# Roofer Clive Tibbett clocked up an ear-shattering 118.7 decibels in the shouting match.
#
# Predicted emotion:  Joy
# Actual emotion   :  Aggression
#
#
#
# That was a long time ago, there's been a lot of water under the bridge, why not talk again?
#
# Predicted emotion:  Optimism
# Actual emotion   :  Optimism
#
#
#
# The ad-man opposite had been casting meaningful glances at her all evening, and the likeliest explanation seemed to be that she and Roger were doing a number together and I'd inadvertently got caught in the crossfire.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Surprise
#
#
#
# We will let bygones be bygones.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Submission
#
#
#
# Then you argue the toss amongst yourselves really, but you've got, you have to.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Submission
#
#
#
# But Ilona's alter-ego remains a bone of contention between them.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Anger
#
#
#
# Dear Father Christmas, I have a bone to pick with you.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Disapproval
#
#
#
# He was really in the bad books over that.
#
# Predicted emotion:  Joy
# Actual emotion   :  Disapproval
#
#
#
# Will you bury the hatchet for a while and dance with me?
#
# Predicted emotion:  Surprise
# Actual emotion   :  Neutral
#
#
#
# Emulating its action against Hirac Inc in the US, Sparc International, the evangelising supporters group for Sun Microsystems Inc's RISC has come down like a ton of bricks on a small UK start-up trying to carve a living out of the Sparc-compatible space.
#
# Predicted emotion:  Joy
# Actual emotion   :  Disapproval
#
#
#
# Come on for crying out loud.
#
# Predicted emotion:  Anger
# Actual emotion   :  Disapproval
#
#
#
# Oh yeah, yeah used to get on my nerves.
#
# Predicted emotion:  Anger
# Actual emotion   :  Anger
#
#
#
# Will you give it a rest love.
#
# Predicted emotion:  Anger
# Actual emotion   :  Disapproval
#
#
#
# Officers at Darlington Borough Council say the gloves are off in the battle for compensation over the town's 12m Dolphin Centre sports complex.
#
# Predicted emotion:  Anger
# Actual emotion   :  Neutral
#
#
#
# He'd go spare.
#
# Predicted emotion:  Surprise
# Actual emotion   :  Anger
#
#
#
# Well, he did rather harp on what a lot of money he spent.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# Hey, d' you hear about the fire-eater who couldn't go anywhere without meeting an old flame, made him feel really hot under the collar.
#
# Predicted emotion:  Anger
# Actual emotion   :  Sadness
#
#
#
# Can't you mind your own business?
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Anger
#
#
#
# Tom's a chap with a temper on a short fuse.
#
# Predicted emotion:  Anger
# Actual emotion   :  Disapproval
#
#
#
# My glasses are all steamed up.
#
# Predicted emotion:  Anger
# Actual emotion   :  Neutral
#
#
#
# It makes my blood boil, it's sacrilege.
#
# Predicted emotion:  Fear
# Actual emotion   :  Anger
#
#
#
# Well I mean now basically the right question about a riff-raff goes back to the old idea whether you're going too far.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# Fortescue is hopping like a cat on hot bricks, demanding something should be done, but he has no more idea than I what can be done.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Anticipation
#
#
#
# Yeah, or hold your breath for fifteen to thirty minutes.
#
# Predicted emotion:  Anticipation
# Actual emotion   :  Neutral
#
#
#
# Thus, for animals in the absence of suffering, ignorance is bliss.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Submission
#
#
#
# You get your legs get stiff you get pins and needles and things like that.
#
# Predicted emotion:  Ambiguous
# Actual emotion   :  Fear
# Put it on at seven o'clock er Emmerdale Farm, but you see when it goes on you feel as though you're tongue tied all be completely anonymous these are all same, but they're different.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# Bernie's such an eager beaver.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Anticipation
#
#
#
# We wished to go the extra mile and give the Chinese side every opportunity to respond.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Ambiguous
#
#
#
# Hold your horses, mate. Here's Charlie now.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Love
#
#
#
# You know, because it was absolute, I was bored to tears.
#
# Predicted emotion:  Sadness
# Actual emotion   :  Disgust
#
#
#
# You have what is called, I believe, a large chip on your shoulder.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Disapproval
#
#
#
# She says it was too close to home and it could easily have been them.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# We watch as friendships come apart at the seams, as lives of promise collapse under the weight of illness or despair or disillusion, but there is a reckless exhilaration about it all.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# Deep down he was knocked out.
#
# Predicted emotion:  Surprise
# Actual emotion   :  Submission
#
#
#
# Herbert Hobden (Holzinger) tried hard to keep a stiff upper lip as he was introduced, with his ten-year-old sister, to his new home
#
# Predicted emotion:  Joy
# Actual emotion   :  Contempt
#
#
#
# 'I expect I shall manage,' she said, determined to look on the bright side.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Optimism
#
#
#
# And Marion Aluinn would find her long nose out of joint.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Contempt
#
#
#
# As Sheila watched him go, she knew that in spite of the hurtful words he had just spoken she would always have a soft spot for the man.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Love
#
#
#
# I need to let off steam.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Anger
#
#
#
# It's steamed up between the layers is that what you're looking at.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Submission
#
#
#
# Dora accepted these ministrations without protest, but Melissa thought she detected a growing restiveness and a thinly veiled relief when at last they said goodnight and returned to their own room.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Submission
#
#
#
# The Milton Humberside whose looks could make a woman turn weak at the knees, and whose ducted fluorescent shelf units were in use from Hartlepool to Exeter and back again?
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Ambiguous
#
#
#
# It's probably the aspirin sweating the chill out.
#
# Predicted emotion:  Joy
# Actual emotion   :  Neutral
#
#
#
# I was absolutely in my element, how did I come over, Jannie?
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Fear
#
#
#
# You're full of the joys of spring at the moment, so make the most of this harmonious period.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Joy
#
#
#
# If attending a wedding or party of close friends, you should have the time of your life
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Anticipation
#
#
#
# Me friend over in Norway, she said she's she got over there and sat down and she thought, yes, she's got the Complete Works of Shakespeare, I'll have a whale of a time trying to read it, she picks up the book, it's all in Norwegian.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Sadness
#
#
#
# Pull the other one, Jo, it's got bells on it.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Anticipation
#
#
#
# Mm, well it's supposed, they're designed to do that aren't they, so at the end of it you're ready to throttle them, when you got the punch line it's on telly.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Disapproval
#
#
#
# Oh, he's on the telly, he must be happy as Larry.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Joy
#
#
#
# You will never look back.
#
# Predicted emotion:  Anger
# Actual emotion   :  Optimism
#
#
#
# He's as pleased as Punch about it.
#
# Predicted emotion:  Joy
# Actual emotion   :  Joy
#
#
#
# He stares at you in raptures.
#
# Predicted emotion:  Joy
# Actual emotion   :  Awe
#
#
#
# She was in seventh heaven.
#
# Predicted emotion:  Joy
# Actual emotion   :  Joy
#
#
#
# Good god ur Susan will be thrilled to bits if you went again.
#
# Predicted emotion:  Joy
# Actual emotion   :  Joy
#
#
#
# Anyway, she's on top of the world.
#
# Predicted emotion:  Joy
# Actual emotion   :  Joy
#
#
#
# Mark'll go bananas I expect.
#
# Predicted emotion:  Sadness
# Actual emotion   :  Anger
#
#
#
# But a man could go nuts sitting around wondering about what might happen.
#
# Predicted emotion:  Anticipation
# Actual emotion   :  Neutral
#
#
#
# The lady with the upright hair who Gloria said had a screw loose, clattered into the bedroom holding out a steaming jug on a tray.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Surprise
#
#
#
# You must be stir crazy.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Sadness
#
#
#
# Everything seems to be done by trial and error.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Disapproval
#
#
#
# He was so wide of the mark that it made her smile.
#
# Predicted emotion:  Sadness
# Actual emotion   :  Joy
#
#
#
# I suppose it was not the done thing for a book of Rambles.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# But in this case the routine's got huggered up, if you'll excuse my French, because someone's short-circuited the standard procedure.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Contempt
#
#
#
# It was asking for trouble especially if you wore glasses like him.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Disapproval
#
#
#
# He reached the level of the bridge, swung his back to the wall, covering the ladder they had just used as Forster made for the door.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Love
#
#
#
# It's always been the bane of my life that you can eat your way through a tuckshop without gaining a pound while I only have to look at a picture of a cream cake to make the scales groan.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Disgust
#
#
#
# I was terrified of him, but I found myself in a horrible Catch 22 situation.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Fear
#
#
#
# There were ominous dark clouds gathering overhead now and a chill wind.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Fear
#
#
#
# He was terribly sorry for her, being how she was, but supposed they all had their cross to bear, like Jazz being coloured, and Gary having Stalin for a father.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Remorse
#
#
#
# BettySinclair adopted a' cross that bridge when we come to it' attitude, which means that she wants the back door left open for a sell-out.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Aggression
#
#
#
# Soon the cat's back and the seal would be high and dry.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Fear
#
#
#
# After being left in the lurch like that, she'd probably have talked.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Anger
#
#
#
# So in fact he knew that he was known as the last resort
#
# Predicted emotion:  Neutral
# Actual emotion   :  Submission
#
#
#
# You heard it could be murder?
#
# Predicted emotion:  Anger
# Actual emotion   :  Surprise
#
#
#
# If we go to any local government official and talk to him about local government finance and how the council tax might work, he will say that it is nonsense and a case of trying to muddle through and paper over the cracks simply to make the package a little more presentable for electoral purposes.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Disapproval
#
#
#
# There's one thing about junk food -- it gives you a quick fix of carbohydrates and sugar.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Joy
#
#
#
# Heavy dependence on sponsorship and arts council cash could spell trouble as the recession hits arts budgets.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Fear
#
#
#
# This too may merely serve to let the situation spiral out of control.
#
# Predicted emotion:  Anticipation
# Actual emotion   :  Surprise
#
#
#
# They always take the easy way out.
#
# Predicted emotion:  Fear
# Actual emotion   :  Neutral
#
#
#
# The launch day saw a few teething problems.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Sadness
#
#
#
# It is inappropriate simply to throw money at these problems in the hope that they will be consequently solved.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Contempt
#
#
#
# There will be no justice and no liberation until the vicious circle is broken and the tyranny of the family is smashed.
#
# Predicted emotion:  Sadness
# Actual emotion   :  Submission
#
#
#
# The Boozebuster went off without a hitch.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# I'll batten down the hatches.
#
# Predicted emotion:  Anticipation
# Actual emotion   :  Anticipation
#
#
#
# But here and there some found action on this very camp, and didn't live to tell the tale
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Fear
#
#
#
# Still, I admit he seems to be able to keep out of harm 's way.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Optimism
#
#
#
# A sudden reckless urge to play with fire made her deliberately provoke him.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Aggression
#
#
#
# If you believe in a drogue, or sea-anchor, up-hook, scratch-in, and rig one, then ride it out and ride with it and tell me when you sight London Bridge.
#
# Predicted emotion:  Sadness
# Actual emotion   :  Ambiguous
# Russia and Ukraine sail close to the wind on Black Sea fleet.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Anticipation
#
#
#
# Forty winks.
#
# Predicted emotion:  Surprise
# Actual emotion   :  Neutral
#
#
#
# The Seychelles lie in the middle of the Indian Ocean, just a few degrees south of the equator.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# The best-selling sexually explicit blockbuster phenomenon is to do with money, nothing to do with literature.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Contempt
#
#
#
# And talking of police, it's a dead cert that the very day a Neighbourhood Watch leaflet arrives, detailing all the recent burglaries.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Disapproval
#
#
#
# She's dead in the water, and out of range of our conventional rescue forces.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Sadness
#
#
#
# And she passed with flying colours
#
# Predicted emotion:  Joy
# Actual emotion   :  Joy
#
#
#
# But I'll tell you who Evans has elected front runner.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# However, if you think your anger is going to get the better of you, then you'd better be realistic and responsible.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Neutral
#
#
#
# Oh go up in smoke
#
# Predicted emotion:  Neutral
# Actual emotion   :  Fear
#
#
#
# The young members section has come on in leaps and bounds in the last few years.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Joy
#
#
#
# To put that off, she needed to make headway that would be noticed in the real world.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Anticipation
#
#
#
# With six shoes under 37, Diadora is likely to make inroads into the budget end of the market.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Anticipation
#
#
#
# That, she thought, will be the moment of truth.
#
# Predicted emotion:  Anticipation
# Actual emotion   :  Anticipation
#
#
#
# We're not you know we're not getting anywhere.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Submission
#
#
#
# It is only through my imaginative shuffling of the aces that we are able to stay ahead of the pack.
#
# Predicted emotion:  Joy
# Actual emotion   :  Anticipation
#
#
#
# Well pack it in both of you.
#
# Predicted emotion:  Anger
# Actual emotion   :  Neutral
#
#
#
# Californians are outsiders over half have travelled thousands of miles for a place in the sun.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Neutral
#
#
#
# I'm sure your spirits will rise to the occasion.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Optimism
#
#
#
# He was like that, always had to be top dog.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Contempt
#
#
#
# The newly-married couple on the up and up.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Love
#
#
#
# He used a wooden spoon to stir the mixture, whistling softly.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Joy
#
#
#
# I hope she doesn't throw the empty glass out into the void to follow its contents; pity the hapless passer-by under that little bolt from the blue.
#
# Predicted emotion:  Surprise
# Actual emotion   :  Anger
#
#
#
# Mrs Friar's jaw dropped.
#
# Predicted emotion:  Surprise
# Actual emotion   :  Surprise
#
#
#
# Good God, he thought, I should like to do something that would really make her jump out of her skin for once.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Surprise
#
#
#
# I can't believe it, wonders will never cease.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Surprise
#
#
#
# If a person were to announce to a policeman that he was about to go to the house of his sworn enemy and beat the living daylights out of him, it would not make sense if the law were that the policeman had to follow the suspect to the locus in quo and only then arrest him.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Disapproval
#
#
#
# Elves and Men had come to blows in the past and might do so again.
#
# Predicted emotion:  Love
# Actual emotion   :  Neutral
#
#
#
# The woman has had to fight tooth and nail, probably, and work much harder, to get at an equal level with the man, so I would suspect that I'm getting value for and quality there by going for the woman.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Trust
#
#
#
# Officers at Darlington Borough Council say the gloves are off in the battle for compensation over the town's 12m Dolphin Centre sports complex.
#
# Predicted emotion:  Anger
# Actual emotion   :  Anger
#
#
#
# Poor man was through the wars, wasn't he?
#
# Predicted emotion:  Surprise
# Actual emotion   :  Sadness
#
#
#
# You've been in the wars rather, haven't you?
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# It is, and no doubt will remain, a moot point whether, in these events, the old parliaments were abolished and replaced by novel creations, or whether a pre-existing parliament was merely renamed.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# I always seem to, I think we, we were always at Stanford Hall that we must, it was a must that we have a good programme because if somebody comes and there's nothing doing, they think well.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Anticipation
#
#
#
# They are not after an olive branch.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Aggression
#
#
#
# He has not given up the running battle between them over the question of form, which started out with his victory on accommodation.
#
# Predicted emotion:  Joy
# Actual emotion   :  Optimism
#
#
#
# We could easily quite often sit on the fence and say the sun may come out or it may stay cloudy all day.
#
# Predicted emotion:  Joy
# Actual emotion   :  Ambiguous
#
#
#
# It's water under the bridge now.
#
# Predicted emotion:  Ambiguous
# Actual emotion   :  Ambiguous
#
#
#
# Though he never forgave me, or my mother for having helped me, both into his world and out of it, he was sufficiently my father to let sleeping dogs lie.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# His production of Mrs Warren's Profession for the National Theatre in 1971 steered cunningly clear of melodrama; his Much Ado About Nothing for the Royal Shakespeare Company in 1971 featured white parasols and sun-dappled lawns that seemed to evoke the world of Turgenev.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# We tricked them into holding fire until we were about a mile out, then all hell broke loose.
#
# Predicted emotion:  Anger
# Actual emotion   :  Aggression
#
#
#
# His officer had recommended him, noticing he was not like everyone else, that he never buckled, and, in life's battle of wills, could stare down any enemy, overcome any weakness.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Trust
#
#
#
# The real bone of contention as if you didn't know is money.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Disapproval
#
#
#
# So Barry Brittlebank has a bone to pick with my grammar.
#
# Predicted emotion:  Anger
# Actual emotion   :  Contempt
#
#
#
# Last night's developments came just 24 hours after today revealed how Diana had agreed a secret pact with Charles to bury the hatchet for the sake of appearances.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Disgust
#
#
#
# Donald and Jean had disappeared and Mary was in a black mood, striding along and making old Donald gasp.
#
# Predicted emotion:  Anger
# Actual emotion   :  Anger
#
#
#
# Once that happens, according to the Meat and Livestock Commission, the floodgates will open and prices will go through the roof.
#
# Predicted emotion:  Fear
# Actual emotion   :  Anticipation
#
#
#
# Most have been exterminated, and good riddance to them.
#
# Predicted emotion:  Contempt
# Actual emotion   :  Disgust
#
#
#
# And people can also get pretty hot under the collar on Central Weekend.
#
# Predicted emotion:  Anticipation
# Actual emotion   :  Anger
#
#
#
# I was going to make a song and dance when we got the 100th subscriber, but 98's near enough.
#
# Predicted emotion:  Sadness
# Actual emotion   :  Neutral
#
#
#
# Usually she flashed back with a Mind Your Own Business, if anyone asked her a question.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Contempt
#
#
#
# Matilda was also beginning to see red.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Anger
#
#
#
# He held his temper on a pretty short fuse, and it was as liable to explode in the face of a headmaster as in that of a dustman.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Anger
#
#
#
# It's a subject that makes my blood boil and disappointments have left me a blister short of swearing.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Anger
#
#
#
# Well, well, well, another humanoid to try my patience.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Optimism
#
#
#
# From July onwards the town of Whaddon had waited with bated breath.
#
# Predicted emotion:  Anticipation
# Actual emotion   :  Anticipation
#
#
#
# He longed for action, yearned to be trusted with high responsibilities, to undertake prodigious feats requiring a cool head, a stout heart and nerves of steel.
#
# Predicted emotion:  Anticipation
# Actual emotion   :  Anticipation
#
#
#
# I'm scared stiff I'm going to lose touch with my children.
#
# Predicted emotion:  Fear
# Actual emotion   :  Fear
# Hold your horses, Mrs Parvis.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Ambiguous
#
#
#
# He was raring to go.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Anticipation
#
#
#
# Wimbledon had been expected to bear the brunt of the FA's displeasure because of their past record.
#
# Predicted emotion:  Fear
# Actual emotion   :  Sadness
#
#
#
# 'OK, A apple,' said Rufus, conscious of his Freudian slip.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# I don't think you should let yourself get worked up like that.
#
# Predicted emotion:  Anticipation
# Actual emotion   :  Anger
#
#
#
# But he was a tough boy and he determined not to go to pieces.
#
# Predicted emotion:  Fear
# Actual emotion   :  Optimism
#
#
#
# Paul didn't keep a stiff upper lip because that was the way that he thought that Christians should behave.
#
# Predicted emotion:  Surprise
# Actual emotion   :  Ambiguous
#
#
#
# No hard feelings, I can understand your concern.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# Has Richard put your nose out of joint?
#
# Predicted emotion:  Surprise
# Actual emotion   :  Submission
#
#
#
# He's as pleased as Punch about it.
#
# Predicted emotion:  Joy
# Actual emotion   :  Joy
#
#
#
# Body language can speak volumes on these occasions.
#
# Predicted emotion:  Joy
# Actual emotion   :  Ambiguous
#
#
#
# He'll be on tenterhooks the whole time, and muttering to the parents things.
#
# Predicted emotion:  Sadness
# Actual emotion   :  Submission
#
#
#
# I was in my element.
#
# Predicted emotion:  Joy
# Actual emotion   :  Joy
#
#
#
# If you are just happy to dream, feast your eyes on this selection of motoring marvels, as seen through the eyes of our motoring correspondent, Peter Jones.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Optimism
#
#
#
# The dog hunt is in full swing on a fresh scent.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Anticipation
#
#
#
# Tonight we're going to paint the town red.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Fear
#
#
#
# Pull the other one.
#
# Predicted emotion:  Joy
# Actual emotion   :  Neutral
#
#
#
# They always saw his jokes before he got to the punch line.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Anticipation
#
#
#
# I get a bit dizzy again and have to take it easy, so what I do is I walk with one arm against the shop windows.
#
# Predicted emotion:  Joy
# Actual emotion   :  Submission
#
#
#
# ...
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Ambiguous
#
#
#
# Mountain biking is wonderful, you're on top of the world while you're pedalling and even higher when you've finished.
#
# Predicted emotion:  Joy
# Actual emotion   :  Joy
#
#
#
# Go bananas for that hour glass figure.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Optimism
#
#
#
# He had to learn through trial and error.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Optimism
#
#
#
# No I don't, but nevertheless, nobody knew only people like us and the neighbours, how that kid was every day when her mother according to Julia had her because it was the done thing.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# She stood with her back to the wall, sheltering from the rain.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# Thought it has a supportive county council and a productive work force, yet it has its cross to bear.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Remorse
#
#
#
# The crux of the matter today is that those children were not listened to or believed when they complained to the very people in whose care we had put them for protection.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# But I won't leave you in the lurch even if that time comes.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Love
#
#
#
# I didn't like that much because it was so smelly, but a necessary evil.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Disgust
#
#
#
# There is no quick fix to defeat terrorism in Northern Ireland.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# Whatever you decide, it pays to look before you leap.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# He left them in safe hands.
#
# Predicted emotion:  Love
# Actual emotion   :  Trust
#
#
#
# Grade Two studying next to a ditch in which they can take cover if the planes should strike today.
#
# Predicted emotion:  Fear
# Actual emotion   :  Neutral
#
#
#
# Malleson had said that half the people were as ready to drop out as he was and he had already dropped out.
#
# Predicted emotion:  Surprise
# Actual emotion   :  Submission
#
#
#
# April Harold Wilson admitted what everyone else already knew, the Bill was a dead duck.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Submission
#
#
#
# And its spectacular fall from grace should serve as a warning.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Fear
#
#
#
# Such deliberation, while the youth of Britain were liable to go up in smoke, outraged many.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Disgust
#
#
#
# Flotation is still not out of the picture, with 1994 being forecast as the big year.
#
# Predicted emotion:  Anticipation
# Actual emotion   :  Optimism
#
#
#
# Faced with a family mutiny, he decided to pack it in and sell up.
#
# Predicted emotion:  Joy
# Actual emotion   :  Submission
#
#
#
# There is more than a touch of rags to riches in the story of the outsize barons.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Optimism
#
#
#
# But if Mr Kohl is now riding high, East German expectations are riding higher.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Anticipation
#
#
#
# The bland and the placid may seem to sail through life but they are either living a superficial existence or else.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Disapproval
#
#
#
# The last two competitors may be called upon to save the day, so always ensure that you keep at least one good finisher.
#
# Predicted emotion:  Awe
# Actual emotion   :  Anticipation
#
#
#
# Not since the surprise smash hit of the year cast a rosy glow over Shore's vehicle.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Anticipation
#
#
#
# A top dog always wants to be top dog.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Ambiguous
#
#
#
# Even so, dismissal should never come as a bolt from the blue, however exalted your place in the corporate hierarchy.
#
# Predicted emotion:  Anticipation
# Actual emotion   :  Neutral
#
#
#
# Ronni's jaw dropped open.
#
# Predicted emotion:  Surprise
# Actual emotion   :  Love
#
#
#
# Why, lo and behold, one of them would solemnly type' Methinks it is like a weasel, and another would almost certainly type' I think therefore I am'.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Neutral
#
#
#
# They'll come to blows with the Kurds, who'll want their own state.
#
# Predicted emotion:  Anger
# Actual emotion   :  Aggression
#
#
#
# Subarctic fishing grounds that were once free for all are now controlled by the country.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# If 13 of them had been nasty, Tit for Tat wouldn't have won.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Ambiguous
#
#
#
# The organisation representing rank and file members of the Republic's army was up in arms today over a new security vetting procedure.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Anger
# My dear Dowdy, out of the question.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Disapproval
#
#
#
# To some extent, that is water under the bridge.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Optimism
#
#
#
# She sounded really cheesed off about it when I said how's your revision going.
#
# Predicted emotion:  Anger
# Actual emotion   :  Neutral
#
#
#
# Give it a rest for several hours after each test.
#
# Predicted emotion:  Joy
# Actual emotion   :  Neutral
#
#
#
# Mind your own business.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Contempt
#
#
#
# Regularly, up to three times a week, they would rant and rave in the streets.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Anger
#
#
#
# Just like Walter Trout, 42 year-old Dave has been making his European debut courtesy of Dutch record label Provogue, and the album' Short Fuse Blues' is receiving very favourable recognition with blues fans everywhere.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Optimism
#
#
#
# I pretended not to notice it, and, as the students listened with bated breath, instructed them to turn to page thirty in Jespersen.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Anticipation
#
#
#
# Don't hold your breath waiting for a reply.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Contempt
#
#
#
# Cis, who knew about it, was scared stiff.
#
# Predicted emotion:  Fear
# Actual emotion   :  Fear
#
#
#
# The basis for his Scottish policy was his conviction that English safety lay in separating France and Scotland, and that conviction reached fever pitch in 1543.
#
# Predicted emotion:  Anticipation
# Actual emotion   :  Neutral
#
#
#
# They fell head over heels in love and my real Mother returned.
#
# Predicted emotion:  Love
# Actual emotion   :  Joy
#
#
#
# There are no hard feelings between ourselves and Camra.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# He was a strong, healthy lad and as pleased as punch to be working with Dad.
#
# Predicted emotion:  Joy
# Actual emotion   :  Joy
#
#
#
# Soon it was dark and the Christmas evening was in full swing.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# Eva was over the moon.
#
# Predicted emotion:  Joy
# Actual emotion   :  Joy
#
#
#
# Set in extensive gardens, the staff at the Sauerhof go out of their way to make visitors welcome, and with the superb health, fitness and beauty programmes on offer, you're sure to leave feeling on top of the world.
#
# Predicted emotion:  Joy
# Actual emotion   :  Optimism
#
#
#
# Most couples feel they are walking on air on their wedding day but for Sellafield's Zoe Whittle and Terry Madrick it was more than just imagination.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Love
#
#
#
# I go bananas, I go spare, I go for you in a big way, I go for you with a knife.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Aggression
#
#
#
# Kenny Schaefer aims to gatecrash the world's top ten by beating York's Commonwealth supermiddleweight champion Henry Wharton on Thursday.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Anticipation
#
#
#
# It's simply asking for trouble.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Disapproval
#
#
#
# Turn around and jump back to the wall.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Fear
#
#
#
# It is not enough for the Minister to pass the buck to the chief inspector of constabulary.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Disapproval
#
#
#
# The taxation of disturbance allowances is a particularly thorny issue.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Disapproval
#
#
#
# When the future seems to be filled with storm clouds, it may appear that the Church has no other recourse but to batten down the hatches and attempt to ride the storm.
#
# Predicted emotion:  Fear
# Actual emotion   :  Anticipation
#
#
#
# I was determined to take a calculated risk.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Anticipation
#
#
#
# One false move and you're dead.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Aggression
#
#
#
# When the kick is delivered, the defender ducks beneath it, well out of harm 's way.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Neutral
#
#
#
# Shift the cattle, work the horses, stick and ball, come back for lunch, an hour's siesta, and you go out like a light I can tell you, then we play chukkas in the afternoon.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Neutral
#
#
#
# A sleeping partner is a person who contributes capital to a business, and receives a share of the profits, but takes no active part in running the business.
#
# Predicted emotion:  Sadness
# Actual emotion   :  Neutral
#
#
#
# It is not unknown for so-called' unspinnable' aircraft to come to grief by getting into a stable spin
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Disapproval
#
#
#
# No one can make a dead duck go' quack' any more than a dead person can be made to speak
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# It is also a nation waiting for her to fall flat on her face.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# Asitz double chair lift operates on Wednesdays and Sundays during high summer to give a flying start to some of the area's prettiest walks.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Neutral
#
#
#
# Existing industries expanded in leaps and bounds.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Neutral
#
#
#
# If he can't make a go of them, nobody can.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Trust
#
#
#
# This and the social side, if any, is what can make or break a holiday.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Neutral
#
#
#
# Australia made inroads into our batting and the moment of truth arrived when Fletch had to go out and bat.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Anticipation
#
#
#
# I used the analogy of a family that goes from rags to riches and back to rags in three or four generations.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# Stir in oodles of special effects and hand the wooden spoon to Robert.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Awe
#
#
#
# A bolt from the blue is how Dounreay described hearing of her thrilling news that she had been awarded the MBE in The Queen's birthday honours.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Surprise
#
#
#
# Then out of the blue, the radio station sacked them.
#
# Predicted emotion:  Surprise
# Actual emotion   :  Surprise
#
#
#
# Fabia was staring at him, struck dumb, when suddenly he let go one of her arms and placed an arm about her shoulders.
#
# Predicted emotion:  Fear
# Actual emotion   :  Surprise
#
#
#
# He and John, the Red Comyn, had come to blows before.
#
# Predicted emotion:  Anger
# Actual emotion   :  Submission
#
#
#
# Planning in the railways has traditionally had an important political dimension that has sometimes been at odds with its use as an internal business tool.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# Obviously these two were at loggerheads.
#
# Predicted emotion:  Anger
# Actual emotion   :  Disapproval
#
#
#
# In the general election campaign Carter continued to harp on the need to clear up the' mess' in Washington.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Neutral
#
#
#
# Alain was getting quite hot under the collar and Dieter seemed to be winding him up on purpose.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Anger
#
#
#
# But you promised we'd see red grouse, wailed an insatiable lad.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Sadness
#
#
#
# A jogger out for his early morning run passed a lone car parked by the side of the road, its windows all steamed up.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
#
#
#
# While it would be going too far to claim that social surveys such as these by themselves induced major political change, it would be dangerous to ignore their significant contribution.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Neutral
#
#
#
# Hold your breath for ten seconds while you have a good stretch.
#
# Predicted emotion:  Sadness
# Actual emotion   :  Neutral
#
#
#
# He's scared stiff of it.
#
# Predicted emotion:  Fear
# Actual emotion   :  Fear
#
#
#
# Diana was blamed for her husband's change of heart.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Contempt
#
#
#
# Come and take potluck, eat humble pie whatever.
#
# Predicted emotion:  Ambiguous
# Actual emotion   :  Ambiguous
#
#
#
# Many centuries of trial and error would elapse before Ireland's dark secret would be revealed.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Surprise
#
#
#
# Even so, asking to be charge capped is surely asking for trouble.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Disapproval
#
#
#
# After a few falls we all managed to get to the bottom of the slope in a snow plough position.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Optimism
#
#
#
# I can't just leave him high and dry either.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Love
#
#
#
# The bank has thus always operated as' lender of last resort' guaranteeing to supply whatever quantity of funds was necessary.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Optimism
#
#
#
# They needed the scrupulous professional integrity which nearly proved such a stumbling block to them in this case.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Neutral
#
#
#
# How can this vicious circle be broken?
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Anger
#
#
#
# Apart from the administrative and cost difficulties, linking nurses pay to performance is fraught with danger, says Mr Thompson.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Anticipation
#
#
#
# The young of many species take cover as soon as an alarm call is given.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Neutral
# It stood at stud at Craigie and half of its earnings were paid to William Dunlop, the sleeping partner.
#
# Predicted emotion:  Sadness
# Actual emotion   :  Neutral
#
#
#
# Give up or go back to square one.
#
# Predicted emotion:  Neutral
# Actual emotion   :  Submission
#
#
#
# The women's confidence increased by leaps and bounds.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Optimism
#
#
#
# They were well aware that large scale investment would make or break the company, but boldly followed their hearts and paid up.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Optimism
#
#
#
# Well, there was a time when it was a bolt from the blue, I mean I've known for a week or two, but we were delighted to receive it.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Joy
#
#
#
# School dinner lady Christine Aspland was paralysed, blinded and struck dumb by a simple headache pill, doctors believe.
#
# Predicted emotion:  Joy
# Actual emotion   :  Neutral
#
#
#
# By this point some of my readers will be up in arms.
#
# Predicted emotion:  Anger
# Actual emotion   :  Neutral
#
#
#
# He did his best to paper over the cracks.
#
# Predicted emotion:  Optimism
# Actual emotion   :  Fear
#
#
#
# Heavy dependence on sponsorship and arts council cash could spell trouble as the recession hits arts budgets.
#
# Predicted emotion:  Disapproval
# Actual emotion   :  Disapproval
#
#
#
# In 1987, when I was chosen to fight my first election at Birmingham's Perry Barr, I was on cloud nine, even though it was a safe Labour seat.
#
# Predicted emotion:  Joy
# Actual emotion   :  Joy
# %  Accuracy when against untrained set:  0.2052821128451381
